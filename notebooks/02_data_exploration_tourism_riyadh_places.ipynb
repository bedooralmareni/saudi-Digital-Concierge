# %% [markdown]
# Saudi Digital Concierge - Data Exploration

# %%
import pandas as pd
import numpy as np
# openpyxl is required by pandas.read_excel() for .xlsx files
try:
    import openpyxl
except ModuleNotFoundError:
    import sys
    # !{sys.executable} -m pip install openpyxl
    import openpyxl

# %%
df = pd.read_csv("C:\\Users\\bedoor.alsulami\\AppData\\Local\\Packages\\PythonSoftwareFoundation.PythonManager_3847v3x7pw1km\\AppData\\saudi-Digital-Concierge\\data\\raw\\riyadh_places\\riyadh_places_8836x9.csv", encoding="utf-8")

df.head()
# Out:
#    id            place_name is_restaurant                   categories  \
# 0   1         Shawarma Alaz    RESTAURANT  Sandwich|Fast Food|Shawarma
# 1   2             Eben Ezar    RESTAURANT               Asian|Japanese
# 2   3              Chowking    RESTAURANT                      Noodles
# 3   4  100 islands delights    RESTAURANT                Asian|Seafood
# 4   5           CUSINA Cafe    RESTAURANT                       Coffee
#
#    average_rating  rate_count granular_category   latitude  longitude
# 0             3.0           3       restaurants  24.645118  46.717640
# 1             3.2           5       restaurants  24.646631  46.717658
# 2             4.5         305       restaurants  24.646194  46.717444
# 3             4.4         239       restaurants  24.646334  46.717329
# 4             4.7          19       restaurants  24.645628  46.717110

# %%
df.shape
df.columns
df.info()
df.isnull().sum()
df.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8836 entries, 0 to 8835
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8836 non-null   int64
#  1   place_name         8836 non-null   str
#  2   is_restaurant      8836 non-null   str
#  3   categories         8822 non-null   str
#  4   average_rating     8836 non-null   float64
#  5   rate_count         8836 non-null   int64
#  6   granular_category  8836 non-null   str
#  7   latitude           8836 non-null   float64
#  8   longitude          8836 non-null   float64
# dtypes: float64(3), int64(2), str(4)
# memory usage: 621.4 KB
# np.int64(0)

# %%
df["is_restaurant"].value_counts()
# Out:
# is_restaurant
# RESTAURANT    8703
# OTHER          133
# Name: count, dtype: int64

# %%
df["granular_category"].value_counts().head(20)
# Out:
# granular_category
# restaurants              8487
# flowers_and_plants        143
# pharmacies                 65
# Butchery                   18
# specialty_and_ethnic       16
# charity                    15
# supermarket                12
# darkstores                 11
# Hypermarket                11
# nuts_and_dried_fruits       7
# Pets                        7
# fruits_and_vegetables       6
# beauty                      5
# dairy_products              5
# electronics                 5
# health_and_wellness         4
# home_and_gifts              4
# mini_market                 3
# optics                      3
# bakery                      2
# Name: count, dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
print("Duplicate IDs:", df["id"].duplicated().sum())
print("Duplicate place names:", df["place_name"].duplicated().sum())
# Out:
# Duplicate rows: 0
# Duplicate IDs: 0
# Duplicate place names: 3587

# %%
print("Duplicate rows:", df.duplicated().sum())

print(
    "Duplicate reviews:",
    df["processed_reviews"].duplicated().sum()
)
# Out:
# Duplicate rows: 5
# Duplicate reviews: 12

# %%
df["average_rating"].describe()
# Out:
# count    8836.000000
# mean        3.809484
# std         1.298362
# min         0.000000
# 25%         3.800000
# 50%         4.200000
# 75%         4.500000
# max         5.000000
# Name: average_rating, dtype: float64

# %%
df["rate_count"].describe()
# Out:
# count     8836.000000
# mean       183.598348
# std        589.104117
# min          0.000000
# 25%          8.000000
# 50%         39.000000
# 75%        158.000000
# max      19808.000000
# Name: rate_count, dtype: float64

# %%
df[df["place_name"].duplicated(keep=False)] \
    .sort_values("place_name") \
    [["id", "place_name", "average_rating", "rate_count", "latitude", "longitude"]] \
    .head(30)
# Out:
#         id         place_name  average_rating  rate_count   latitude  \
# 4291  4292          % Arabica             4.6          53  24.766907
# 1935  1936          % Arabica             4.5         120  24.731831
# 6904  6905  &nbsp;Vidro Pizza             0.0           0  24.772487
# 7545  7546  &nbsp;Vidro Pizza             5.0           1  24.806922
# 3656  3657        1/4 Dhabiha             5.0           1  24.804230
# 1617  1618        1/4 Dhabiha             0.0           0  24.792609
# 1903  1904        1/4 Dhabiha             0.0           0  24.731978
# 5135  5136          1/4 kabab             2.4           7  24.808611
# 3927  3928          1/4 kabab             3.9          65  24.814708
# 7507  7508            12 Cups             4.3         213  24.731400
# 5495  5496            12 Cups             4.4          82  24.765552
# 2653  2654            12 Cups             4.4         164  24.803461
# 5370  5371  180 Degree Bakery             0.0           0  24.728626
# ...

# %%
df[df["average_rating"] == 0][
    ["place_name", "average_rating", "rate_count", "latitude", "longitude"]
].head(20)
# Out:
#                         place_name  average_rating  rate_count   latitude  \
# 15                            BANA             0.0           0  24.633701
# 24                      Alharfoosh             0.0           0  24.658017
# 29                       NG Beauty             0.0           0  24.640424
# 34   Methaas Bakery &amp; Desserts             0.0           0  24.628968
# 173                         Nuiava             0.0           0  24.676850
# 174                    Mass Sweets             0.0           0  24.676850
# 175                    El Artisano             0.0           0  24.676850
# 177               Flavonoid Sweets             0.0           0  24.676850
# 178                       Lagouter             0.0           0  24.676850
# 179                           Raqy             0.0           0  24.676850
# 181                          Kenaz             0.0           0  24.676850
# 203                     Noodle Way             0.0           0  24.663826
# ...

# %%
print("Rating = 0:", (df["average_rating"] == 0).sum())
print("Rate count = 0:", (df["rate_count"] == 0).sum())
# Out:
# Rating = 0: 749
# Rate count = 0: 749
